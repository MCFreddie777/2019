# %% [markdown]
# ## Preprocessing - Extract, Transform, Load

# %%
# %load_ext autoreload
# %autoreload all

# %%
# dependencies
import pandas as pd
import numpy as np

# %%
# local modules
import sys
sys.path.append("..")

from _helpers import constants
from _helpers import functions as hf
from _helpers.preprocess import preprocess

# %% [markdown]
# ## Load the data

# %%
df_train = pd.read_parquet(constants.DROPPED_TRAIN)

# %% [markdown]
# We will be loading the data in chunks to save memory. Grouping by user - session pairs so we don't cut off any session in half.

# %%
chunk_size = round(1e5)

# %%
unique_sessions = df_train[['user_id', 'session_id']].drop_duplicates()['session_id']
chunks =  [unique_sessions[i:i + chunk_size] for i in range(0, len(unique_sessions), chunk_size)]

# %% [markdown]
# From now on we will be working with a single chunk and then preprocess the rest at once.

# %%
df_chunk = df_train[df_train['session_id'].isin(chunks[0])]

# %% [markdown]
# ## Extract features

# %% [markdown]
# ### Select only columns with reference item_id

# %% [markdown]
# Select only those action_type rows, which contain item_id in reference column

# %%
item_reference_action_type_cols = [
    'clickout item', 'interaction item deals', 'interaction item image',
    'interaction item info', 'interaction item rating', 'search for item'
]

# %%
df_chunk = df_chunk[df_chunk.action_type.isin(item_reference_action_type_cols)].rename(columns={'reference': 'referenced_item'})
df_chunk
# Out:
#               user_id     session_id   timestamp  step  \
# 1        00RL8Z82B2Z1  aff3928535f48  1541037522     2
# 2        00RL8Z82B2Z1  aff3928535f48  1541037522     3
# 3        00RL8Z82B2Z1  aff3928535f48  1541037532     4
# 4        00RL8Z82B2Z1  aff3928535f48  1541037532     5
# 5        00RL8Z82B2Z1  aff3928535f48  1541037532     6
# ...               ...            ...         ...   ...
# 2103317  0O42Q0CC10C0  782b7db1fdbe5  1541486883     4
# 2103318  0O42Q0CC10C0  782b7db1fdbe5  1541486883     5
# 2103319  0O42Q0CC10C0  782b7db1fdbe5  1541487048     6
# 2103320  0O42Q0CC10C0  782b7db1fdbe5  1541487048     7
# 2103321  0O42Q0CC10C0  782b7db1fdbe5  1541487048     8
#
#                     action_type referenced_item platform  \
# 1        interaction item image          666856       AU
# 2        interaction item image          666856       AU
# 3        interaction item image          666856       AU
# 4        interaction item image          109038       AU
# 5        interaction item image          666856       AU
# ...                         ...             ...      ...
# 2103317  interaction item image         3205604       PH
# 2103318  interaction item image         3205604       PH
# 2103319  interaction item image         3760746       PH
# 2103320  interaction item image         3760746       PH
# 2103321  interaction item image         3760746       PH
#
#                             city   device current_filters impressions prices
# 1              Sydney, Australia   mobile             NaN         NaN    NaN
# 2              Sydney, Australia   mobile             NaN         NaN    NaN
# 3              Sydney, Australia   mobile             NaN         NaN    NaN
# 4              Sydney, Australia   mobile             NaN         NaN    NaN
# 5              Sydney, Australia   mobile             NaN         NaN    NaN
# ...                          ...      ...             ...         ...    ...
# 2103317  Vigan City, Philippines  desktop             NaN         NaN    NaN
# 2103318  Vigan City, Philippines  desktop             NaN         NaN    NaN
# 2103319  Vigan City, Philippines  desktop             NaN         NaN    NaN
# 2103320  Vigan City, Philippines  desktop             NaN         NaN    NaN
# 2103321  Vigan City, Philippines  desktop             NaN         NaN    NaN
#
# [1870712 rows x 12 columns]

# %% [markdown]
# ### Add previous_item column

# %% [markdown]
# Get item id of previous interaction of a user in a session

# %%
df_chunk.insert(
    loc=df_chunk.columns.get_loc("referenced_item") + 1,  # Insert previous item after reference column
    column='previous_item',
    value=df_chunk.sort_values(
        by=["user_id", "session_id", "timestamp", "step"],
        ascending=[True, True, True, True]
    )
    .groupby(["user_id"])["referenced_item"]
    .shift(1)
)
df_chunk.head(10)
# Out:
#          user_id     session_id   timestamp  step             action_type  \
# 1   00RL8Z82B2Z1  aff3928535f48  1541037522     2  interaction item image
# 2   00RL8Z82B2Z1  aff3928535f48  1541037522     3  interaction item image
# 3   00RL8Z82B2Z1  aff3928535f48  1541037532     4  interaction item image
# 4   00RL8Z82B2Z1  aff3928535f48  1541037532     5  interaction item image
# 5   00RL8Z82B2Z1  aff3928535f48  1541037532     6  interaction item image
# 6   00RL8Z82B2Z1  aff3928535f48  1541037532     7  interaction item image
# 7   00RL8Z82B2Z1  aff3928535f48  1541037532     8  interaction item image
# 8   00RL8Z82B2Z1  aff3928535f48  1541037542     9  interaction item image
# 9   00RL8Z82B2Z1  aff3928535f48  1541037542    10  interaction item image
# 10  00RL8Z82B2Z1  aff3928535f48  1541037542    11  interaction item image
#
#    referenced_item previous_item platform               city  device  \
# 1           666856           NaN       AU  Sydney, Australia  mobile
# 2           666856        666856       AU  Sydney, Australia  mobile
# 3           666856        666856       AU  Sydney, Australia  mobile
# 4           109038        666856       AU  Sydney, Australia  mobile
# 5           666856        109038       AU  Sydney, Australia  mobile
# 6           109038        666856       AU  Sydney, Australia  mobile
# 7           666856        109038       AU  Sydney, Australia  mobile
# 8           109038        666856       AU  Sydney, Australia  mobile
# 9           109038        109038       AU  Sydney, Australia  mobile
# 10          109038        109038       AU  Sydney, Australia  mobile
#
#    current_filters impressions prices
# 1              NaN         NaN    NaN
# 2              NaN         NaN    NaN
# 3              NaN         NaN    NaN
# 4              NaN         NaN    NaN
# 5              NaN         NaN    NaN
# 6              NaN         NaN    NaN
# 7              NaN         NaN    NaN
# 8              NaN         NaN    NaN
# 9              NaN         NaN    NaN
# 10             NaN         NaN    NaN

# %% [markdown]
# ### Explode impressions and its prices into separate rows

# %% [markdown]
# As impressions are only present during clickouts, and we have multiple action_types, we will create a new column, interacted_item which will contain either impressions, or referenced item (item subject of action_type)

# %%
df_chunk.insert(
    loc=df_chunk.columns.get_loc("referenced_item") + 1,  # Insert previous item after reference column
    column='interacted_item',
    value=np.where(
        df_chunk.impressions.isna(),
        df_chunk.referenced_item,
        df_chunk.impressions
    )
)

# %%
df_chunk.loc[:, "prices"] = np.where(
        df_chunk.prices.isna(),
        "",
        df_chunk.prices
    )
    
df_chunk = hf.explode(df_chunk, ['interacted_item', 'prices'])

# %%
# Rename prices since it represents single value now
df_chunk = df_chunk.rename(columns={'prices': 'price'})
    
# Don't need this column anymore as it
df_chunk = df_chunk.drop(columns="impressions")

# %%
df_chunk = hf.reorder_column(df_chunk, df_chunk.columns.get_loc("interacted_item"), df_chunk.columns.get_loc("referenced_item") + 1)
df_chunk = hf.reorder_column(df_chunk, df_chunk.columns.get_loc("price"), df_chunk.columns.get_loc("interacted_item") + 1)
df_chunk
# Out:
#               user_id     session_id   timestamp  step  \
# 0        00RL8Z82B2Z1  aff3928535f48  1541037522     2
# 1        00RL8Z82B2Z1  aff3928535f48  1541037522     3
# 2        00RL8Z82B2Z1  aff3928535f48  1541037532     4
# 3        00RL8Z82B2Z1  aff3928535f48  1541037532     5
# 4        00RL8Z82B2Z1  aff3928535f48  1541037532     6
# ...               ...            ...         ...   ...
# 6252783  0O42Q0CC10C0  782b7db1fdbe5  1541486883     4
# 6252784  0O42Q0CC10C0  782b7db1fdbe5  1541486883     5
# 6252785  0O42Q0CC10C0  782b7db1fdbe5  1541487048     6
# 6252786  0O42Q0CC10C0  782b7db1fdbe5  1541487048     7
# 6252787  0O42Q0CC10C0  782b7db1fdbe5  1541487048     8
#
#                     action_type referenced_item interacted_item price  \
# 0        interaction item image          666856          666856
# 1        interaction item image          666856          666856
# 2        interaction item image          666856          666856
# 3        interaction item image          109038          109038
# 4        interaction item image          666856          666856
# ...                         ...             ...             ...   ...
# 6252783  interaction item image         3205604         3205604
# 6252784  interaction item image         3205604         3205604
# 6252785  interaction item image         3760746         3760746
# 6252786  interaction item image         3760746         3760746
# 6252787  interaction item image         3760746         3760746
#
#         previous_item platform                     city   device  \
# 0                 NaN       AU        Sydney, Australia   mobile
# 1              666856       AU        Sydney, Australia   mobile
# 2              666856       AU        Sydney, Australia   mobile
# 3              666856       AU        Sydney, Australia   mobile
# 4              109038       AU        Sydney, Australia   mobile
# ...               ...      ...                      ...      ...
# 6252783       3205604       PH  Vigan City, Philippines  desktop
# 6252784       3205604       PH  Vigan City, Philippines  desktop
# 6252785       3205604       PH  Vigan City, Philippines  desktop
# 6252786       3760746       PH  Vigan City, Philippines  desktop
# 6252787       3760746       PH  Vigan City, Philippines  desktop
#
#         current_filters
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 6252783             NaN
# 6252784             NaN
# 6252785             NaN
# 6252786             NaN
# 6252787             NaN
#
# [6252788 rows x 13 columns]

# %% [markdown]
# The size of our dataset in rows just went up, but now we have single action and single information about item.

# %% [markdown]
# The `referenced_item` and `interacted_item` seems to be same, but it isn't. For example during clickouts, in `interacted_item` value represents impression, but `referenced_item` is the item user has clicked out.

# %% [markdown]
# ### User modelling - add information about how many times did user interact with the item

# %%
df_chunk.insert(
    loc=df_chunk.columns.get_loc("interacted_item") + 1,  # Insert previous item after reference column
    column='user_interacted_item_interaction_count',
    value=(
        df_chunk
        .groupby(["user_id", "interacted_item"])
        .cumcount()
    )
)
df_chunk
# Out:
#               user_id     session_id   timestamp  step  \
# 0        00RL8Z82B2Z1  aff3928535f48  1541037522     2
# 1        00RL8Z82B2Z1  aff3928535f48  1541037522     3
# 2        00RL8Z82B2Z1  aff3928535f48  1541037532     4
# 3        00RL8Z82B2Z1  aff3928535f48  1541037532     5
# 4        00RL8Z82B2Z1  aff3928535f48  1541037532     6
# ...               ...            ...         ...   ...
# 6252783  0O42Q0CC10C0  782b7db1fdbe5  1541486883     4
# 6252784  0O42Q0CC10C0  782b7db1fdbe5  1541486883     5
# 6252785  0O42Q0CC10C0  782b7db1fdbe5  1541487048     6
# 6252786  0O42Q0CC10C0  782b7db1fdbe5  1541487048     7
# 6252787  0O42Q0CC10C0  782b7db1fdbe5  1541487048     8
#
#                     action_type referenced_item interacted_item  \
# 0        interaction item image          666856          666856
# 1        interaction item image          666856          666856
# 2        interaction item image          666856          666856
# 3        interaction item image          109038          109038
# 4        interaction item image          666856          666856
# ...                         ...             ...             ...
# 6252783  interaction item image         3205604         3205604
# 6252784  interaction item image         3205604         3205604
# 6252785  interaction item image         3760746         3760746
# 6252786  interaction item image         3760746         3760746
# 6252787  interaction item image         3760746         3760746
#
#          user_interacted_item_interaction_count price previous_item platform  \
# 0                                             0                 NaN       AU
# 1                                             1              666856       AU
# 2                                             2              666856       AU
# 3                                             0              666856       AU
# 4                                             3              109038       AU
# ...                                         ...   ...           ...      ...
# 6252783                                       3             3205604       PH
# 6252784                                       4             3205604       PH
# 6252785                                       2             3205604       PH
# 6252786                                       3             3760746       PH
# 6252787                                       4             3760746       PH
#
#                             city   device current_filters
# 0              Sydney, Australia   mobile             NaN
# 1              Sydney, Australia   mobile             NaN
# 2              Sydney, Australia   mobile             NaN
# 3              Sydney, Australia   mobile             NaN
# 4              Sydney, Australia   mobile             NaN
# ...                          ...      ...             ...
# 6252783  Vigan City, Philippines  desktop             NaN
# 6252784  Vigan City, Philippines  desktop             NaN
# 6252785  Vigan City, Philippines  desktop             NaN
# 6252786  Vigan City, Philippines  desktop             NaN
# 6252787  Vigan City, Philippines  desktop             NaN
#
# [6252788 rows x 14 columns]

# %% [markdown]
# ### Narrow to clickouts

# %% [markdown]
# Since we already aquired all information we needed from different action types, we can drop them now.

# %%
df_chunk = df_chunk[df_chunk.action_type == "clickout item"] \
    .drop(columns="action_type") \
    .rename(columns={"interacted_item": "impressed_item"}) \
    .rename(columns={"user_interacted_item_interaction_count": "user_impressed_item_interaction_count"})
df_chunk
# Out:
#               user_id     session_id   timestamp  step referenced_item  \
# 12       00RL8Z82B2Z1  aff3928535f48  1541037543    14          109038
# 13       00RL8Z82B2Z1  aff3928535f48  1541037543    14          109038
# 14       00RL8Z82B2Z1  aff3928535f48  1541037543    14          109038
# 15       00RL8Z82B2Z1  aff3928535f48  1541037543    14          109038
# 16       00RL8Z82B2Z1  aff3928535f48  1541037543    14          109038
# ...               ...            ...         ...   ...             ...
# 6252777  0O42Q0CC10C0  782b7db1fdbe5  1541485321     2         3760746
# 6252778  0O42Q0CC10C0  782b7db1fdbe5  1541485321     2         3760746
# 6252779  0O42Q0CC10C0  782b7db1fdbe5  1541485321     2         3760746
# 6252780  0O42Q0CC10C0  782b7db1fdbe5  1541485321     2         3760746
# 6252781  0O42Q0CC10C0  782b7db1fdbe5  1541485321     2         3760746
#
#         impressed_item  user_impressed_item_interaction_count price  \
# 12             3400638                                      0    95
# 13             1253714                                      0    66
# 14             3367857                                      0   501
# 15             5100540                                      0   112
# 16             1088584                                      0    95
# ...                ...                                    ...   ...
# 6252777        2506344                                      1    49
# 6252778        1449677                                      1    68
# 6252779        6410668                                      1    38
# 6252780       10037154                                      1    14
# 6252781        6522036                                      1    46
#
#         previous_item platform                     city   device  \
# 12             109038       AU        Sydney, Australia   mobile
# 13             109038       AU        Sydney, Australia   mobile
# 14             109038       AU        Sydney, Australia   mobile
# 15             109038       AU        Sydney, Australia   mobile
# 16             109038       AU        Sydney, Australia   mobile
# ...               ...      ...                      ...      ...
# 6252777       3760746       PH  Vigan City, Philippines  desktop
# 6252778       3760746       PH  Vigan City, Philippines  desktop
# 6252779       3760746       PH  Vigan City, Philippines  desktop
# 6252780       3760746       PH  Vigan City, Philippines  desktop
# 6252781       3760746       PH  Vigan City, Philippines  desktop
#
#         current_filters
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# ...                 ...
# 6252777             NaN
# 6252778             NaN
# 6252779             NaN
# 6252780             NaN
# 6252781             NaN
#
# [4581355 rows x 13 columns]

# %% [markdown]
# ### Add information about price

# %% [markdown]
# We want to find out whether user might be interested in the impression because of the price, if it's below or above mean of all impressions

# %%
df_chunk.loc[:, 'price'] = df_chunk['price'].astype(int)

df_mean_price = df_chunk \
    .groupby(['user_id', 'session_id', 'timestamp', 'step', 'impressed_item']) \
    .agg(mean_price=('price', 'mean')) \
    .reset_index()
    
df_chunk = df_mean_price.merge(
    df_chunk,
    on=['user_id', 'session_id', 'step', 'timestamp', 'impressed_item'],
)
    
df_chunk['price_above_impression_mean'] = (df_chunk['price'] > df_chunk['mean_price']).astype(int)
df_chunk = hf.reorder_column(df_chunk, df_chunk.columns.get_loc("price_above_impression_mean"), df_chunk.columns.get_loc("price") + 1)
df_chunk
# Out:
#               user_id     session_id   timestamp  step impressed_item  \
# 0        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110976
# 1        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110979
# 2        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110981
# 3        0004IOZI7CKF  0146f7cb014ba  1541266796     3         150904
# 4        0004IOZI7CKF  0146f7cb014ba  1541266796     3         159015
# ...               ...            ...         ...   ...            ...
# 4581350  ZZZHCOZVA3IM  9555befa755ea  1541351984     3         478871
# 4581351  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5188226
# 4581352  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5659850
# 4581353  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5790750
# 4581354  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        8459162
#
#          mean_price referenced_item  user_impressed_item_interaction_count  \
# 0              70.0         2627602                                      0
# 1              78.0         2627602                                      0
# 2              96.0         2627602                                      0
# 3             150.0         2627602                                      0
# 4             117.0         2627602                                      0
# ...             ...             ...                                    ...
# 4581350        92.0         3148916                                      0
# 4581351        45.0         3148916                                      0
# 4581352        95.0         3148916                                      0
# 4581353       324.0         3148916                                      0
# 4581354        43.0         3148916                                      0
#
#          price  price_above_impression_mean previous_item platform  \
# 0           70                            0       3381482       DE
# 1           78                            0       3381482       DE
# 2           96                            0       3381482       DE
# 3          150                            0       3381482       DE
# 4          117                            0       3381482       DE
# ...        ...                          ...           ...      ...
# 4581350     92                            0       3148916       BR
# 4581351     45                            0       3148916       BR
# 4581352     95                            0       3148916       BR
# 4581353    324                            0       3148916       BR
# 4581354     43                            0       3148916       BR
#
#                            city  device current_filters
# 0               Valencia, Spain  tablet             NaN
# 1               Valencia, Spain  tablet             NaN
# 2               Valencia, Spain  tablet             NaN
# 3               Valencia, Spain  tablet             NaN
# 4               Valencia, Spain  tablet             NaN
# ...                         ...     ...             ...
# 4581350  Rio de Janeiro, Brazil  mobile             NaN
# 4581351  Rio de Janeiro, Brazil  mobile             NaN
# 4581352  Rio de Janeiro, Brazil  mobile             NaN
# 4581353  Rio de Janeiro, Brazil  mobile             NaN
# 4581354  Rio de Janeiro, Brazil  mobile             NaN
#
# [4581355 rows x 15 columns]

# %% [markdown]
# ### Impression position

# %% [markdown]
# Users might me more likely to click on items which are at top of the page than to scroll on the page, therefore we add a column which says impression position could be helpful

# %%
df_chunk.insert(
    loc=df_chunk.columns.get_loc("impressed_item") + 1,  # Insert previous item after reference column
    column='impressed_item_position',
    value=(
        df_chunk
        .groupby(["user_id", "session_id", "timestamp", "step"])
        .cumcount() + 1
    )
)
df_chunk
# Out:
#               user_id     session_id   timestamp  step impressed_item  \
# 0        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110976
# 1        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110979
# 2        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110981
# 3        0004IOZI7CKF  0146f7cb014ba  1541266796     3         150904
# 4        0004IOZI7CKF  0146f7cb014ba  1541266796     3         159015
# ...               ...            ...         ...   ...            ...
# 4581350  ZZZHCOZVA3IM  9555befa755ea  1541351984     3         478871
# 4581351  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5188226
# 4581352  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5659850
# 4581353  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5790750
# 4581354  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        8459162
#
#          impressed_item_position  mean_price referenced_item  \
# 0                              1        70.0         2627602
# 1                              2        78.0         2627602
# 2                              3        96.0         2627602
# 3                              4       150.0         2627602
# 4                              5       117.0         2627602
# ...                          ...         ...             ...
# 4581350                       21        92.0         3148916
# 4581351                       22        45.0         3148916
# 4581352                       23        95.0         3148916
# 4581353                       24       324.0         3148916
# 4581354                       25        43.0         3148916
#
#          user_impressed_item_interaction_count  price  \
# 0                                            0     70
# 1                                            0     78
# 2                                            0     96
# 3                                            0    150
# 4                                            0    117
# ...                                        ...    ...
# 4581350                                      0     92
# 4581351                                      0     45
# 4581352                                      0     95
# 4581353                                      0    324
# 4581354                                      0     43
#
#          price_above_impression_mean previous_item platform  \
# 0                                  0       3381482       DE
# 1                                  0       3381482       DE
# 2                                  0       3381482       DE
# 3                                  0       3381482       DE
# 4                                  0       3381482       DE
# ...                              ...           ...      ...
# 4581350                            0       3148916       BR
# 4581351                            0       3148916       BR
# 4581352                            0       3148916       BR
# 4581353                            0       3148916       BR
# 4581354                            0       3148916       BR
#
#                            city  device current_filters
# 0               Valencia, Spain  tablet             NaN
# 1               Valencia, Spain  tablet             NaN
# 2               Valencia, Spain  tablet             NaN
# 3               Valencia, Spain  tablet             NaN
# 4               Valencia, Spain  tablet             NaN
# ...                         ...     ...             ...
# 4581350  Rio de Janeiro, Brazil  mobile             NaN
# 4581351  Rio de Janeiro, Brazil  mobile             NaN
# 4581352  Rio de Janeiro, Brazil  mobile             NaN
# 4581353  Rio de Janeiro, Brazil  mobile             NaN
# 4581354  Rio de Janeiro, Brazil  mobile             NaN
#
# [4581355 rows x 16 columns]

# %% [markdown]
# ### User modelling - Add last_interacted column

# %% [markdown]
# Add a column which presents whether impressed_item the last interacted_item. User is more likely to clickout the item (therefore have it in the referenced_item), if they interacted with it just in the previous session step

# %% [markdown]
# E.g. they interacted with the image of the item, therefore if impressed_item equals previous_item, there is a higher chance to be in referenced_item column (therefore our prediction target)

# %% [markdown]
# ite

# %%
df_chunk.insert(
    loc=df_chunk.columns.get_loc("user_impressed_item_interaction_count") + 1,
    column='is_last_interacted',
    value=(df_chunk["previous_item"] == df_chunk["impressed_item"]).astype(int)
)
df_chunk
# Out:
#               user_id     session_id   timestamp  step impressed_item  \
# 0        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110976
# 1        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110979
# 2        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110981
# 3        0004IOZI7CKF  0146f7cb014ba  1541266796     3         150904
# 4        0004IOZI7CKF  0146f7cb014ba  1541266796     3         159015
# ...               ...            ...         ...   ...            ...
# 4581350  ZZZHCOZVA3IM  9555befa755ea  1541351984     3         478871
# 4581351  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5188226
# 4581352  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5659850
# 4581353  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5790750
# 4581354  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        8459162
#
#          impressed_item_position  mean_price referenced_item  \
# 0                              1        70.0         2627602
# 1                              2        78.0         2627602
# 2                              3        96.0         2627602
# 3                              4       150.0         2627602
# 4                              5       117.0         2627602
# ...                          ...         ...             ...
# 4581350                       21        92.0         3148916
# 4581351                       22        45.0         3148916
# 4581352                       23        95.0         3148916
# 4581353                       24       324.0         3148916
# 4581354                       25        43.0         3148916
#
#          user_impressed_item_interaction_count  is_last_interacted  price  \
# 0                                            0                   0     70
# 1                                            0                   0     78
# 2                                            0                   0     96
# 3                                            0                   0    150
# 4                                            0                   0    117
# ...                                        ...                 ...    ...
# 4581350                                      0                   0     92
# 4581351                                      0                   0     45
# 4581352                                      0                   0     95
# 4581353                                      0                   0    324
# 4581354                                      0                   0     43
#
#          price_above_impression_mean previous_item platform  \
# 0                                  0       3381482       DE
# 1                                  0       3381482       DE
# 2                                  0       3381482       DE
# 3                                  0       3381482       DE
# 4                                  0       3381482       DE
# ...                              ...           ...      ...
# 4581350                            0       3148916       BR
# 4581351                            0       3148916       BR
# 4581352                            0       3148916       BR
# 4581353                            0       3148916       BR
# 4581354                            0       3148916       BR
#
#                            city  device current_filters
# 0               Valencia, Spain  tablet             NaN
# 1               Valencia, Spain  tablet             NaN
# 2               Valencia, Spain  tablet             NaN
# 3               Valencia, Spain  tablet             NaN
# 4               Valencia, Spain  tablet             NaN
# ...                         ...     ...             ...
# 4581350  Rio de Janeiro, Brazil  mobile             NaN
# 4581351  Rio de Janeiro, Brazil  mobile             NaN
# 4581352  Rio de Janeiro, Brazil  mobile             NaN
# 4581353  Rio de Janeiro, Brazil  mobile             NaN
# 4581354  Rio de Janeiro, Brazil  mobile             NaN
#
# [4581355 rows x 17 columns]

# %% [markdown]
# ## Encoding

# %% [markdown]
# We don't need string information about device platform or city, we can transform those categorical values into codes

# %%
df_chunk = df_chunk.copy()
categorical_attributes = ['device', 'platform', 'city']

for cat in categorical_attributes:
    df_chunk[cat] = df_chunk[cat].astype('category').cat.codes
    
df_chunk
# Out:
#               user_id     session_id   timestamp  step impressed_item  \
# 0        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110976
# 1        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110979
# 2        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110981
# 3        0004IOZI7CKF  0146f7cb014ba  1541266796     3         150904
# 4        0004IOZI7CKF  0146f7cb014ba  1541266796     3         159015
# ...               ...            ...         ...   ...            ...
# 4581350  ZZZHCOZVA3IM  9555befa755ea  1541351984     3         478871
# 4581351  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5188226
# 4581352  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5659850
# 4581353  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5790750
# 4581354  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        8459162
#
#          impressed_item_position  mean_price referenced_item  \
# 0                              1        70.0         2627602
# 1                              2        78.0         2627602
# 2                              3        96.0         2627602
# 3                              4       150.0         2627602
# 4                              5       117.0         2627602
# ...                          ...         ...             ...
# 4581350                       21        92.0         3148916
# 4581351                       22        45.0         3148916
# 4581352                       23        95.0         3148916
# 4581353                       24       324.0         3148916
# 4581354                       25        43.0         3148916
#
#          user_impressed_item_interaction_count  is_last_interacted  price  \
# 0                                            0                   0     70
# 1                                            0                   0     78
# 2                                            0                   0     96
# 3                                            0                   0    150
# 4                                            0                   0    117
# ...                                        ...                 ...    ...
# 4581350                                      0                   0     92
# 4581351                                      0                   0     45
# 4581352                                      0                   0     95
# 4581353                                      0                   0    324
# 4581354                                      0                   0     43
#
#          price_above_impression_mean previous_item  platform   city  device  \
# 0                                  0       3381482        14  11474       2
# 1                                  0       3381482        14  11474       2
# 2                                  0       3381482        14  11474       2
# 3                                  0       3381482        14  11474       2
# 4                                  0       3381482        14  11474       2
# ...                              ...           ...       ...    ...     ...
# 4581350                            0       3148916         7   9075       1
# 4581351                            0       3148916         7   9075       1
# 4581352                            0       3148916         7   9075       1
# 4581353                            0       3148916         7   9075       1
# 4581354                            0       3148916         7   9075       1
#
#         current_filters
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4581350             NaN
# 4581351             NaN
# 4581352             NaN
# 4581353             NaN
# 4581354             NaN
#
# [4581355 rows x 17 columns]

# %% [markdown]
# ## Using item metadata

# %%
df_meta = pd.read_csv(constants.METADATA, dtype={'item_id': str})
df_meta
# Out:
#          item_id                                         properties
# 0           5101  Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 1           5416  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 2           5834  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 3           5910  Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 4           6066  Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...
# ...          ...                                                ...
# 927137  11199990                                  House / Apartment
# 927138  11236100                                  House / Apartment
# 927139  11260526                                  House / Apartment
# 927140  11263712                                  House / Apartment
# 927141  11275316                                              Hotel
#
# [927142 rows x 2 columns]

# %% [markdown]
# Separate properties into arrays

# %%
df_meta.loc[:, 'properties'] = df_meta.loc[:, 'properties'].str.split("|")
df_meta
# Out:
#          item_id                                         properties
# 0           5101  [Satellite TV, Golf Course, Airport Shuttle, C...
# 1           5416  [Satellite TV, Cosmetic Mirror, Safe (Hotel), ...
# 2           5834  [Satellite TV, Cosmetic Mirror, Safe (Hotel), ...
# 3           5910  [Satellite TV, Sailing, Cosmetic Mirror, Telep...
# 4           6066  [Satellite TV, Sailing, Diving, Cosmetic Mirro...
# ...          ...                                                ...
# 927137  11199990                                [House / Apartment]
# 927138  11236100                                [House / Apartment]
# 927139  11260526                                [House / Apartment]
# 927140  11263712                                [House / Apartment]
# 927141  11275316                                            [Hotel]
#
# [927142 rows x 2 columns]

# %% [markdown]
# ### Parsing rating from item metadata

# %% [markdown]
# Rozdelenie "|" separovaných hodnôt na list.

# %%
 rating_map = {
    'Satisfactory Rating': 7.0,
    'Good Rating': 7.5,
    'Very Good Rating': 8.0,
    'Excellent Rating': 8.5
}
        
# Properties may contain multiple ratings, all of those which apply, we need to find a maximum
df_meta['impressed_item_rating'] = df_meta['properties']\
    .apply(lambda x: max([rating_map[key] for key in x if key in rating_map], default=None))

df_meta
# Out:
#          item_id                                         properties  \
# 0           5101  [Satellite TV, Golf Course, Airport Shuttle, C...
# 1           5416  [Satellite TV, Cosmetic Mirror, Safe (Hotel), ...
# 2           5834  [Satellite TV, Cosmetic Mirror, Safe (Hotel), ...
# 3           5910  [Satellite TV, Sailing, Cosmetic Mirror, Telep...
# 4           6066  [Satellite TV, Sailing, Diving, Cosmetic Mirro...
# ...          ...                                                ...
# 927137  11199990                                [House / Apartment]
# 927138  11236100                                [House / Apartment]
# 927139  11260526                                [House / Apartment]
# 927140  11263712                                [House / Apartment]
# 927141  11275316                                            [Hotel]
#
#         impressed_item_rating
# 0                        7.50
# 1                        8.50
# 2                        8.00
# 3                        7.50
# 4                        7.50
# ...                       ...
# 927137                   7.75
# 927138                   7.75
# 927139                   7.75
# 927140                   7.75
# 927141                   7.75
#
# [927142 rows x 3 columns]

# %% [markdown]
# ### Merging metadata

# %% [markdown]
# Now using this metadata about item rating, we may merge the values with dataset

# %%
df_chunk = df_chunk.merge(
    df_meta[['item_id','impressed_item_rating']],
    left_on='impressed_item',
    right_on='item_id',
    how='left'
)

df_chunk = df_chunk.drop(columns='item_id')

# Fill NaN with mean
df_chunk['impressed_item_rating'] = df_chunk['impressed_item_rating'].fillna(df_chunk['impressed_item_rating'].mean())

df_chunk = hf.reorder_column(df_chunk, df_chunk.columns.get_loc("impressed_item_rating"), df_chunk.columns.get_loc("impressed_item_position") + 1)
df_chunk
# Out:
#               user_id     session_id   timestamp  step impressed_item  \
# 0        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110976
# 1        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110979
# 2        0004IOZI7CKF  0146f7cb014ba  1541266796     3         110981
# 3        0004IOZI7CKF  0146f7cb014ba  1541266796     3         150904
# 4        0004IOZI7CKF  0146f7cb014ba  1541266796     3         159015
# ...               ...            ...         ...   ...            ...
# 4581350  ZZZHCOZVA3IM  9555befa755ea  1541351984     3         478871
# 4581351  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5188226
# 4581352  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5659850
# 4581353  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        5790750
# 4581354  ZZZHCOZVA3IM  9555befa755ea  1541351984     3        8459162
#
#          impressed_item_position  impressed_item_rating  mean_price  \
# 0                              1                   7.50        70.0
# 1                              2                   8.00        78.0
# 2                              3                   8.00        96.0
# 3                              4                   8.50       150.0
# 4                              5                   8.00       117.0
# ...                          ...                    ...         ...
# 4581350                       21                   8.00        92.0
# 4581351                       22                   8.00        45.0
# 4581352                       23                   8.50        95.0
# 4581353                       24                   8.50       324.0
# 4581354                       25                   7.75        43.0
#
#         referenced_item  user_impressed_item_interaction_count  \
# 0               2627602                                      0
# 1               2627602                                      0
# 2               2627602                                      0
# 3               2627602                                      0
# 4               2627602                                      0
# ...                 ...                                    ...
# 4581350         3148916                                      0
# 4581351         3148916                                      0
# 4581352         3148916                                      0
# 4581353         3148916                                      0
# 4581354         3148916                                      0
#
#          is_last_interacted  price  price_above_impression_mean previous_item  \
# 0                         0     70                            0       3381482
# 1                         0     78                            0       3381482
# 2                         0     96                            0       3381482
# 3                         0    150                            0       3381482
# 4                         0    117                            0       3381482
# ...                     ...    ...                          ...           ...
# 4581350                   0     92                            0       3148916
# 4581351                   0     45                            0       3148916
# 4581352                   0     95                            0       3148916
# 4581353                   0    324                            0       3148916
# 4581354                   0     43                            0       3148916
#
#          platform   city  device current_filters
# 0              14  11474       2             NaN
# 1              14  11474       2             NaN
# 2              14  11474       2             NaN
# 3              14  11474       2             NaN
# 4              14  11474       2             NaN
# ...           ...    ...     ...             ...
# 4581350         7   9075       1             NaN
# 4581351         7   9075       1             NaN
# 4581352         7   9075       1             NaN
# 4581353         7   9075       1             NaN
# 4581354         7   9075       1             NaN
#
# [4581355 rows x 18 columns]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This was an example of ETL on one chunk out of training data. We also need to preprocess all training and testing data.

# %%
# Iterate over the chunks of training data
for i, chunk in enumerate(chunks):
    df_chunk = df_train[df_train['session_id'].isin(chunk)]
    processed_chunk = preprocess(df_chunk, df_meta)

    processed_chunk.to_parquet(constants.PREPROCESSED(i, 'train'), index=False)
    print(f"Chunk {i} saved to {constants.PREPROCESSED(i, 'train')}.")
# Out:
# Chunk 0 saved to /home/data/preprocessed/train_0.parquet.
# Chunk 1 saved to /home/data/preprocessed/train_1.parquet.
# Chunk 2 saved to /home/data/preprocessed/train_2.parquet.
# Chunk 3 saved to /home/data/preprocessed/train_3.parquet.
# Chunk 4 saved to /home/data/preprocessed/train_4.parquet.
# Chunk 5 saved to /home/data/preprocessed/train_5.parquet.
# Chunk 6 saved to /home/data/preprocessed/train_6.parquet.

# %% [markdown]
# And do the same with test data

# %%
# load data
df_test = pd.read_parquet(constants.DROPPED_TEST)

# Get N chunks of unique user-sessions pairs (N = chunk_size)
unique_sessions = df_test[['user_id', 'session_id']].drop_duplicates()['session_id']
chunks = [unique_sessions[i:i + chunk_size] for i in range(0, len(unique_sessions), chunk_size)]

# Iterate over the chunks
for i, chunk in enumerate(chunks):
    df_chunk = df_test[df_test['session_id'].isin(chunk)]
    processed_chunk = preprocess(df_chunk, df_meta)

    processed_chunk.to_parquet(constants.PREPROCESSED(i, 'test'), index=False)
    print(f"Chunk {i} saved to {constants.PREPROCESSED(i, 'test')}.")
# Out:
# Chunk 0 saved to /home/data/preprocessed/test_0.parquet.
# Chunk 1 saved to /home/data/preprocessed/test_1.parquet.
# Chunk 2 saved to /home/data/preprocessed/test_2.parquet.
