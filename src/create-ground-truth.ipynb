# %%
# %load_ext autoreload
# %autoreload all

# %%
import pandas as pd
import numpy as np
import random

from _helpers import constants
from _helpers import functions as f

# %%
df_test = pd.read_csv(constants.TEST)

# %%
df = df_test.copy()
df
# Out:
#               user_id     session_id   timestamp  step  \
# 0        004A07DM0IDW  1d688ec168932  1541555614     1
# 1        004A07DM0IDW  1d688ec168932  1541555614     2
# 2        004A07DM0IDW  1d688ec168932  1541555696     3
# 3        004A07DM0IDW  1d688ec168932  1541555707     4
# 4        004A07DM0IDW  1d688ec168932  1541555717     5
# ...               ...            ...         ...   ...
# 3782330  ZZ39YE45SZIE  f5db4092ec9fc  1541551888     3
# 3782331  ZZ39YE45SZIE  f5db4092ec9fc  1541551891     4
# 3782332  ZZ39YE45SZIE  f5db4092ec9fc  1541551899     5
# 3782333  ZZ39YE45SZIE  f5db4092ec9fc  1541551945     6
# 3782334  ZZCM39YKI3NR  6226bde1465e7  1541601178     1
#
#                     action_type reference platform                   city  \
# 0        interaction item image   2059240       CO  Santa Marta, Colombia
# 1        interaction item image   2059240       CO  Santa Marta, Colombia
# 2                 clickout item   1050068       CO  Santa Marta, Colombia
# ...

# %%
df_target = f.get_target_rows(df)
df_target
# Out:
#               user_id     session_id   timestamp  step    action_type  \
# 6        004A07DM0IDW  1d688ec168932  1541555799     7  clickout item
# 8        009RGHI3G9A3  f05ab0de907e2  1541570940     2  clickout item
# 10       00Y1Z24X8084  26b6d294d66e7  1541651823     2  clickout item
# 15       01V3WDTDM5CU  07628a0f5be0b  1541575643     5  clickout item
# 61       02AOAVF9PVYH  4a01c3afbc224  1541681278    46  clickout item
# ...               ...            ...         ...   ...            ...
# 3782317  ZXGCLNDBW84E  e73c90b6f448e  1541699269   466  clickout item
# 3782325  ZYG4MMKT847V  0f128fd98b4e3  1541634384     4  clickout item
# 3782327  ZYMVSZ5A3KQI  8cd16c29b733b  1541695019     2  clickout item
# 3782333  ZZ39YE45SZIE  f5db4092ec9fc  1541551945     6  clickout item
# 3782334  ZZCM39YKI3NR  6226bde1465e7  1541601178     1  clickout item
#
#         reference platform                      city   device  \
# 6             NaN       CO     Santa Marta, Colombia   mobile
# ...

# %% [markdown]
# Máme viac clickout_item v rámci jednej session? Existujú duplikáty?

# %%
df_target.duplicated(subset=['session_id']).unique()
# Out:
# array([False])

# %% [markdown]
# ## Random Ground Truth

# %%
df_gt = df_target.copy()
df_gt.loc[:, "reference"] = df_target.loc[:, "impressions"].str.split("|").map(lambda x: random.choice(x))

# %%
df_gt
# Out:
#               user_id     session_id   timestamp  step    action_type  \
# 6        004A07DM0IDW  1d688ec168932  1541555799     7  clickout item
# 8        009RGHI3G9A3  f05ab0de907e2  1541570940     2  clickout item
# 10       00Y1Z24X8084  26b6d294d66e7  1541651823     2  clickout item
# 15       01V3WDTDM5CU  07628a0f5be0b  1541575643     5  clickout item
# 61       02AOAVF9PVYH  4a01c3afbc224  1541681278    46  clickout item
# ...               ...            ...         ...   ...            ...
# 3782317  ZXGCLNDBW84E  e73c90b6f448e  1541699269   466  clickout item
# 3782325  ZYG4MMKT847V  0f128fd98b4e3  1541634384     4  clickout item
# 3782327  ZYMVSZ5A3KQI  8cd16c29b733b  1541695019     2  clickout item
# 3782333  ZZ39YE45SZIE  f5db4092ec9fc  1541551945     6  clickout item
# 3782334  ZZCM39YKI3NR  6226bde1465e7  1541601178     1  clickout item
#
#         reference platform                      city   device  \
# 6         3442272       CO     Santa Marta, Colombia   mobile
# ...

# %%
df_gt.to_csv(constants.GROUND_TRUTH, index=False)

# %% [markdown]
# ## Cheapest Ground Truth

# %%
min_price_idx = df_target.loc[:, "prices"].str.split("|").apply(lambda x: np.argmin(list(map(int,x))))
min_price_idx
# Out:
# 6          19
# 8           1
# 10         10
# 15          0
# 61          0
#            ..
# 3782317    23
# 3782325    15
# 3782327     1
# 3782333     8
# 3782334     9
# Name: prices, Length: 253573, dtype: int64

# %%
df_target.loc[:, "impressions"].str.split("|")
# Out:
# 6          [2059240, 2033381, 1724779, 127131, 399441, 10...
# 8                                        [10884872, 7065316]
# 10         [2714480, 4476010, 3843244, 3833012, 9017890, ...
# 15         [3565720, 2947584, 4115018, 2039671, 3836538, ...
# 61         [1451247, 559056, 1045096, 1963879, 693596, 19...
#                                  ...
# 3782317    [916029, 1650015, 326846, 503361, 1326068, 477...
# 3782325    [1089752, 4103676, 2033145, 2684451, 2053814, ...
# 3782327    [364796, 1299248, 4891790, 381296, 1345175, 96...
# 3782333    [9925140, 2625125, 5779140, 7365168, 5849342, ...
# 3782334    [46149, 109974, 46119, 8333280, 12455, 1185556...
# Name: impressions, Length: 253573, dtype: object

# %%
df_gt.loc[:,'reference'] = [l[idx] for idx,l in zip(list(min_price_idx), df_target.loc[:,'impressions'].str.split("|"))]

# %%
df_gt.to_csv(constants.GROUND_TRUTH, index=False)
